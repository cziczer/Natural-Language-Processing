# %% [markdown]
# # Multiword expressions identification and extraction

# %%
import collections
import math
import os
import requests
from spacy.lang.pl import Polish
import time

# %% [markdown]
# 1. Use SpaCy tokenizer API to tokenize the text from the law corpus.

# %%
nlp = Polish()
tokenizer = nlp.tokenizer

# %%
text_tokenized = {}

for root, _, files in os.walk('./ustawy'):
    for file_name in files:
        path = os.path.join(root, file_name)
        with open(path, encoding='utf-8') as file:
            content = file.read()
            tokens = [
                token.text.lower().strip()
                for token
                in tokenizer(content)
            ]
            text_tokenized[path] = [token for token in tokens if token != '']

# %% [markdown]
# 2. Compute bigram counts of downcased tokens.
#
# Given the sentence: "The quick brown fox jumps over the
#    lazy dog.", the bigram counts are as follows:
#    1. "the quick": 1
#    1. "quick brown": 1
#    1. "brown fox": 1
#    1. ...
#    1. "dog .": 1

# %%
def count_ngrams(tokens, n=2):
    ngram_dict = collections.defaultdict(int)
    for words in zip(*[tokens[offset:] for offset in (range(n))]):
        ngram_dict[' '.join(words)] += 1
    return ngram_dict

# %%
bigram_counts = collections.defaultdict(int)

for file, tokens in text_tokenized.items():
    for bigram, count in count_ngrams(tokens).items():
        bigram_counts[bigram] += count

# %%
sorted(bigram_counts.items(), key=lambda bigram_count: -bigram_count[1])[:20]
# Out:
# [('art .', 83778),
#  ('ust .', 53552),
#  ('poz .', 45198),
#  (', poz', 43188),
#  ('. 1', 39953),
#  ('- -', 36547),
#  ('r .', 33015),
#  ('w art', 32042),
#  (', o', 29926),
#  ('mowa w', 28471),
#  ('. 2', 26714),
#  ('w ust', 23557),
#  ('. art', 22922),
#  (', w', 22495),
#  ('. nr', 21433),
#  ('2 .', 21285),
#  ('1 .', 21267),
#  (', z', 19680),
#  (') w', 18311),
#  ('. 3', 17167)]

# %% [markdown]
# 3.Discard bigrams containing characters other than letters. Make sure that you discard the invalid entries after computing the bigram counts.

# %%
bigram_counts = {
    bigram: count
    for (bigram, count)
    in bigram_counts.items()
    if all([token.isalpha() for token in bigram.split(' ')])
}

# %%
sorted(bigram_counts.items(), key=lambda bigram_count: -bigram_count[1])[:20]
# Out:
# [('w art', 32042),
#  ('mowa w', 28471),
#  ('w ust', 23557),
#  ('o których', 13884),
#  ('których mowa', 13857),
#  ('otrzymuje brzmienie', 9553),
#  ('z dnia', 9527),
#  ('o którym', 9184),
#  ('którym mowa', 9171),
#  ('do spraw', 8715),
#  ('i nr', 8435),
#  ('dodaje się', 8195),
#  ('w brzmieniu', 7280),
#  ('w drodze', 7127),
#  ('na podstawie', 6674),
#  ('stosuje się', 6535),
#  ('w przypadku', 6021),
#  ('o której', 5529),
#  ('której mowa', 5510),
#  ('w zakresie', 5454)]

# %% [markdown]
# 4. Use pointwise mutual information to compute the measure for all pairs of words.

# %%
unigram_counts = collections.defaultdict(int)

for file, tokens in text_tokenized.items():
    for unigram, count in count_ngrams(tokens, n=1).items():
        unigram_counts[unigram] += count

unigram_counts = {
    unigram: count
    for (unigram, count)
    in unigram_counts.items()
    if unigram.isalpha()
}

# %%
sorted(unigram_counts.items(), key=lambda unigram_count: -unigram_count[1])[:20]
# Out:
# [('w', 201224),
#  ('i', 90009),
#  ('art', 83804),
#  ('z', 82443),
#  ('o', 64776),
#  ('do', 60735),
#  ('ust', 53636),
#  ('na', 50647),
#  ('się', 45886),
#  ('lub', 45800),
#  ('poz', 45224),
#  ('nr', 44950),
#  ('oraz', 33558),
#  ('r', 33177),
#  ('mowa', 28783),
#  ('nie', 22990),
#  ('przez', 20953),
#  ('pkt', 19124),
#  ('dnia', 17954),
#  ('których', 17932)]

# %%
total_unigram_count = sum(unigram_counts.values())
total_bigram_count = sum(bigram_counts.values())

# %%
def pmi2(bigram, separator=' '):
    first_token, second_token = bigram.split(separator)
    first_token_p = unigram_counts[first_token] / total_unigram_count
    second_token_p = unigram_counts[second_token] / total_unigram_count
    bigram_p = bigram_counts[bigram] / total_bigram_count
    return math.log2(bigram_p / (first_token_p * second_token_p))

# %%
bigram_pmi = {
    bigram: pmi2(bigram)
    for (bigram, count)
    in bigram_counts.items()
}

# %%
list(bigram_pmi.items())[:10]
# Out:
# [('ustawa z', 4.375258347743362),
#  ('z dnia', 4.903851080276138),
#  ('o ratyfikacji', 5.17245512966816),
#  ('ratyfikacji traktatu', 11.564000660854001),
#  ('traktatu o', 4.118694392752504),
#  ('o otwartych', 2.078537266280521),
#  ('otwartych przestworzach', 17.061709028468528),
#  ('przestworzach art', 4.794440384163163),
#  ('upoważnia się', 6.333256839662903),
#  ('się prezydenta', 1.3596246931781315)]

# %% [markdown]
# 5. Sort the word pairs according to that measure in the descending order and determine top 10 entries.

# %%
sorted(bigram_pmi.items(), key=lambda bigram_pmi: -bigram_pmi[1])[:10]
# Out:
# [('ugaszone zapałki', 22.149171869718867),
#  ('rozgarnia ściółkę', 22.149171869718867),
#  ('reakcjami psychofizycznymi', 22.149171869718867),
#  ('papaver somniferum', 22.149171869718867),
#  ('makiem ogrodowym', 22.149171869718867),
#  ('owocujące wierzchołki', 22.149171869718867),
#  ('resztek pożniwnych', 22.149171869718867),
#  ('dziele pielęgnowania', 22.149171869718867),
#  ('virtus et', 22.149171869718867),
#  ('et fraternitas', 22.149171869718867)]

# %% [markdown]
# 6. Filter bigrams with number of occurrences lower than 5. Determine top 10 entries for the remaining dataset (>=5 occurrences).

# %%
filtered_bigram_pmi = {
    bigram: pmi
    for (bigram, pmi)
    in bigram_pmi.items()
    if bigram_counts[bigram] >= 5
}

# %%
sorted(filtered_bigram_pmi.items(), key=lambda bigram_pmi: -bigram_pmi[1])[:10]
# Out:
# [('świeckie przygotowujące', 19.827243774831505),
#  ('klęskami żywiołowymi', 19.827243774831505),
#  ('obcowania płciowego', 19.827243774831505),
#  ('nietykalność cielesną', 19.827243774831505),
#  ('młyny kulowe', 19.827243774831505),
#  ('młynki młotkowe', 19.827243774831505),
#  ('najnowszych zdobyczy', 19.827243774831505),
#  ('teryto rialnego', 19.827243774831505),
#  ('obiegów chłodzących', 19.827243774831505),
#  ('otworami wiertniczymi', 19.827243774831505)]

# %% [markdown]
# 7. Use KRNNT or Clarin-PL API(https://ws.clarin-pl.eu/tager.shtml) to tag and lemmatize the corpus.

# %%
# !docker pull djstrong/krnnt2
# Out:
# Using default tag: latest
# Got permission denied while trying to connect to the Docker daemon socket at unix:///var/run/docker.sock: Post "http://%2Fvar%2Frun%2Fdocker.sock/v1.24/images/create?fromImage=djstrong%2Fkrnnt2&tag=latest": dial unix /var/run/docker.sock: connect: permission denied

# %%
# !docker run -it -p "9200:9200" djstrong/krnnt2
# Out:
# docker: Got permission denied while trying to connect to the Docker daemon socket at unix:///var/run/docker.sock: Post "http://%2Fvar%2Frun%2Fdocker.sock/v1.24/containers/create": dial unix /var/run/docker.sock: connect: permission denied.
# See 'docker run --help'.

# %%
# !python3 /home/krnnt/krnnt/krnnt_serve.py /home/krnnt/krnnt/data
# Out:
# python3: can't open file '/home/krnnt/krnnt/krnnt_serve.py': [Errno 2] No such file or directory

# %%
print(requests.post('http://localhost:9200', data='Ala ma kota.').text, end='')
# Out:
# Ala	none
# 	Ala	subst:sg:nom:f	disamb
# ma	space
# 	mieć	fin:sg:ter:imperf	disamb
# kota	space
# 	kot	subst:sg:acc:m2	disamb
# .	none
# 	.	interp	disamb

# %%
print(list(lemmatized_acts.values())[0][:50])
lemmatized_acts_copy = lemmatized_acts
# Out:
# ['dziennik:brev', '.:interp', 'ustawa:brev', '.:interp', 'z:prep', '1995:adj', 'rok:brev', '.:interp', 'numer:brev', '14:num', ',:interp', 'pozycja:brev', '.:interp', '62:adj', 'ustawa:subst', 'z:prep', 'dzień:subst', '15:adj', 'grudzień:subst', '1994:adj', 'rok:brev', '.:interp', 'o:prep', 'ratyfikacja:subst', 'traktat:subst', 'o:prep', 'otworzyć:ppas', 'przestworze:subst', 'artykuł:brev', '.:interp', '1:adj', '.:interp', 'upoważniać:fin', 'się:qub', 'prezydent:subst', 'rzeczpospolita:subst', 'polski:adj', 'do:prep', 'ratyfikować:ger', 'traktat:subst', 'o:prep', 'otwarty:adj', 'przestworze:subst', ',:interp', 'podpisać:ppas', 'w:prep', 'helsinki:subst', 'dzień:subst', '24:adj', 'marzec:subst']

# %% [markdown]
# 8. Using the tagged corpus compute bigram statistic for the tokens containing:
#  - a. lemmatized, downcased word
#   - b. morphosyntactic category of the word (subst, fin, adj, etc.)

# %%
def count_ngrams(tokens, n=2):
    ngram_dict = collections.defaultdict(int)
    for words in zip(*[tokens[offset:] for offset in (range(n))]):
        ngram_dict[' '.join(words)] += 1
    return ngram_dict

# %%
lemmatized_bigram_counts = collections.defaultdict(int)

for _, lemmatized_act in lemmatized_acts.items():
    for bigram, count in count_ngrams(lemmatized_act).items():
        lemmatized_bigram_counts[bigram] += count

# %%
sorted(lemmatized_bigram_counts.items(), key=lambda bigram_count: -bigram_count[1])[:20]
# Out:
# [('artykuł:brev .:interp', 83738),
#  ('ustęp:brev .:interp', 53315),
#  ('pozycja:brev .:interp', 45197),
#  (',:interp pozycja:brev', 43168),
#  ('.:interp 1:adj', 39986),
#  ('-:interp -:interp', 36548),
#  ('rok:brev .:interp', 33021),
#  ('w:prep artykuł:brev', 32035),
#  (',:interp o:prep', 29913),
#  ('o:prep który:adj', 28656),
#  ('który:adj mowa:subst', 28538),
#  ('mowa:subst w:prep', 28473),
#  ('.:interp 2:adj', 26408),
#  ('w:prep ustęp:brev', 23536),
#  ('.:interp artykuł:brev', 22917),
#  (',:interp w:prep', 22544),
#  ('.:interp numer:brev', 21433),
#  ('1:adj .:interp', 21311),
#  ('2:adj .:interp', 21119),
#  (',:interp z:prep', 20015)]

# %% [markdown]
# 9. Discard bigrams containing characters other than letters
#
# For example: "Ala ma kota", which is tagged as:
#    ```
#    Ala	none
#            Ala	subst:sg:nom:f	disamb
#    ma	space
#            mieć	fin:sg:ter:imperf	disamb
#    kota	space
#            kot	subst:sg:acc:m2	disamb
#    .	none
#            .	interp	disamb
#    ```
#    the algorithm should return the following bigrams: `ala:subst mieć:fin` and `mieć:fin kot:subst`.

# %%
lemmatized_bigram_counts = {
    bigram: count
    for (bigram, count)
    in lemmatized_bigram_counts.items()
    if all([token.split(':')[0].isalpha() and token != 'X:X' for token in bigram.split(' ')])
}

# %%
sorted(lemmatized_bigram_counts.items(), key=lambda bigram_count: -bigram_count[1])[:20]
# Out:
# [('w:prep artykuł:brev', 32035),
#  ('o:prep który:adj', 28656),
#  ('który:adj mowa:subst', 28538),
#  ('mowa:subst w:prep', 28473),
#  ('w:prep ustęp:brev', 23536),
#  ('z:prep dzień:subst', 11360),
#  ('otrzymywać:fin brzmienie:subst', 10535),
#  ('określić:ppas w:prep', 9715),
#  ('do:prep sprawa:subst', 8718),
#  ('ustawa:subst z:prep', 8625),
#  ('właściwy:adj do:prep', 8535),
#  ('i:conj numer:brev', 8435),
#  ('dodawać:fin się:qub', 8196),
#  ('minister:subst właściwy:adj', 7933),
#  ('w:prep brzmienie:subst', 7277),
#  ('w:prep droga:subst', 7128),
#  ('w:prep przypadek:subst', 6776),
#  ('na:prep podstawa:subst', 6681),
#  ('stosować:fin się:qub', 6535),
#  ('się:qub wyraz:subst', 6077)]

# %% [markdown]
# 10. Compute the same statistics as for the non-lemmatized words (i.e. PMI) and print top-10 entries with at least 5 occurrences.

# %%
lemmatized_unigram_counts = collections.defaultdict(int)

for file, tokens in lemmatized_acts.items():
    for unigram, count in count_ngrams(tokens, n=1).items():
        lemmatized_unigram_counts[unigram] += count

lemmatized_unigram_counts = {
    unigram: count
    for (unigram, count)
    in lemmatized_unigram_counts.items()
    if all([token.split(':')[0].isalpha() and token != 'X:X' for token in unigram.split(' ')])

}

# %%
sorted(lemmatized_unigram_counts.items(), key=lambda unigram_count: -unigram_count[1])[:20]
# Out:
# [('w:prep', 202615),
#  ('i:conj', 89442),
#  ('z:prep', 87987),
#  ('artykuł:brev', 83742),
#  ('o:prep', 64713),
#  ('do:prep', 60761),
#  ('ustęp:brev', 53335),
#  ('na:prep', 50651),
#  ('który:adj', 49380),
#  ('się:qub', 45888),
#  ('lub:conj', 45800),
#  ('pozycja:brev', 45197),
#  ('numer:brev', 44868),
#  ('oraz:conj', 33564),
#  ('rok:brev', 33050),
#  ('mowa:subst', 28804),
#  ('dzień:subst', 27885),
#  ('on:ppron3', 26330),
#  ('ustawa:subst', 24933),
#  ('nie:qub', 22748)]

# %%
total_lemmitized_unigram_count = sum(lemmatized_unigram_counts.values())
total_lemmitized_bigram_count = sum(lemmatized_bigram_counts.values())

# %%
def lemmitized_pmi2(bigram, separator=' '):
    first_token, second_token = bigram.split(separator)
    first_token_p = lemmatized_unigram_counts[first_token] / total_lemmitized_unigram_count
    second_token_p = lemmatized_unigram_counts[second_token] / total_lemmitized_unigram_count
    bigram_p = lemmatized_bigram_counts[bigram] / total_lemmitized_bigram_count
    return math.log2(bigram_p / (first_token_p * second_token_p))

# %%
lemmatized_bigram_pmi = {
    bigram: lemmitized_pmi2(bigram)
    for (bigram, count)
    in lemmatized_bigram_counts.items()
}

# %%
lemmatized_bigram_pmi
# Out:
# {'ustawa:subst z:prep': 4.194234150253142,
#  'z:prep dzień:subst': 4.430167834122352,
#  'o:prep ratyfikacja:subst': 5.162559567983826,
#  'ratyfikacja:subst traktat:subst': 11.304248987681536,
#  'traktat:subst o:prep': 3.885995129588055,
#  'o:prep otworzyć:ppas': -0.09785744783534765,
#  'otworzyć:ppas przestworze:subst': 14.883910491715254,
#  'przestworze:subst artykuł:brev': 4.797033278660855,
#  'upoważniać:fin się:qub': 6.2601721686508665,
#  'się:qub prezydent:subst': 0.5930478602104122,
#  'prezydent:subst rzeczpospolita:subst': 9.080420348845651,
#  'rzeczpospolita:subst polski:adj': 9.054383699450149,
#  'polski:adj do:prep': -0.7758221452800045,
#  'do:prep ratyfikować:ger': 6.107835945613037,
#  'ratyfikować:ger traktat:subst': 12.638944378642776,
#  'o:prep otwarty:adj': -0.0009959085827589633,
#  'otwarty:adj przestworze:subst': 13.395809530246687,
#  'podpisać:ppas w:prep': 3.6984725293901377,
#  'w:prep helsinki:subst': 4.522315574236311,
#  'helsinki:subst dzień:subst': 7.383495381882156,
#  'ustawa:subst wchodzić:fin': 6.756624196213833,
#  'wchodzić:fin w:prep': 4.320189001365424,
#  'w:prep życie:subst': 4.233390078447054,
#  'życie:subst z:prep': 3.0777023059143773,
#  'dzień:subst ogłoszenie:subst': 6.6630737038504835,
#  'o:prep zmiana:subst': 3.825455701194743,
#  'zmiana:subst ustawa:subst': 4.567547370281203,
#  'ustawa:subst o:prep': 2.2670638048587963,
#  'o:prep podatek:subst': 3.8175719897605624,
#  'podatek:subst i:conj': 0.8416614538308849,
#  'i:conj opłata:subst': 1.3223368660080792,
#  'opłata:subst lokalny:adj': 7.3992823574558235,
#  'lokalny:adj artykuł:brev': -1.465061566709324,
#  'w:prep ustawa:subst': 2.2817755620424345,
#  'i:conj numer:brev': 3.2908053010133367,
#  'oraz:conj z:prep': 2.76185904048402,
#  'wprowadzać:fin się:qub': 6.543825446657485,
#  'się:qub następujący:adj': 6.250481407036215,
#  'następujący:adj zmiana:subst': 8.899012678178504,
#  'w:prep artykuł:brev': 3.136013190538632,
#  'otrzymywać:fin brzmienie:subst': 7.969985101077702,
#  'przyczepa:subst i:conj': 3.429013710011318,
#  'i:conj naczepa:subst': 4.001592486276642,
#  'naczepa:subst o:prep': 3.0534518754396176,
#  'o:prep ładowność:subst': 4.618732010299074,
#  'ładowność:subst powyżej:prep': 10.767609935684934,
#  'z:prep wyjątek:subst': 5.6108980512182045,
#  'wyjątek:subst wykorzystywać:ppas': 3.056905534112206,
#  'wykorzystywać:ppas na:prep': 3.021409792419829,
#  'na:prep cel:subst': 3.9620408671244776,
#  'cel:subst rolniczy:adj': 4.809252668922917,
#  'rolniczy:adj przez:prep': -1.492159936174262,
#  'przez:prep podatnik:subst': 4.75513817492928,
#  'podatnik:subst podatek:subst': 6.648036129719896,
#  'podatek:subst rolny:adj': 6.390815216580386,
#  'dotychczasowy:adj treść:subst': 9.441201952919428,
#  'treść:subst oznaczać:fin': 10.435097507098059,
#  'oznaczać:fin się:qub': 5.270815249558743,
#  'się:qub jako:conj': 4.5254080029929895,
#  'jako:conj ustęp:brev': 3.61391202150519,
#  'i:conj dodawać:fin': 2.4644301187741267,
#  'dodawać:fin się:qub': 6.625453541954668,
#  'się:qub ustęp:brev': 2.6861602231583444,
#  'w:prep brzmienie:subst': 3.226999209596268,
#  'przy:prep określać:ger': 8.187225428798609,
#  'określać:ger stawka:subst': 6.122359259270775,
#  'o:prep który:adj': 5.38383949881537,
#  'który:adj mowa:subst': 6.5456728757231915,
#  'mowa:subst w:prep': 4.505640909901936,
#  'w:prep ustęp:brev': 3.3421021431472457,
#  'rada:subst gmina:subst': 6.7086003039033155,
#  'gmina:subst móc:fin': 3.266486872124051,
#  'móc:fin uwzględniać:inf': 4.1473532435506035,
#  'uwzględniać:inf rodzaj:subst': 6.412666364568909,
#  'rodzaj:subst środek:subst': 2.9416261043703753,
#  'środek:subst transportowy:adj': 7.935483660641138,
#  'masa:subst całkowity:adj': 9.166500210587468,
#  'nacisk:subst na:prep': 3.3931108835566657,
#  'na:prep siodło:subst': 5.937431399780476,
#  'siodło:subst ciągnik:subst': 15.683091482327159,
#  'ciągnik:subst albo:conj': 4.179928290860108,
#  'albo:conj liczba:subst': 0.26815547387184324,
#  'liczba:subst miejsce:subst': 3.272386375790596,
#  'miejsce:subst do:prep': -0.5479313459371291,
#  'do:prep siedzenie:subst': 5.259839039058087,
#  'tekst:subst ustawa:subst': 5.870947362491198,
#  'ustawa:subst przyjąć:ppas': 5.150850290321537,
#  'przyjąć:ppas przez:prep': 6.138440156898196,
#  'przez:prep senat:subst': 5.695622644691133,
#  'senat:subst bez:prep': 8.764584675123077,
#  'bez:prep poprawka:subst': 9.870439307764237,
#  'poprawka:subst ustawa:subst': 6.490480386942358,
#  'ratyfikacja:subst konwencja:subst': 11.366142633783868,
#  'konwencja:subst o:prep': 4.537573686653946,
#  'o:prep prawo:subst': 0.08010688559807087,
#  'prawo:subst osoba:subst': 0.056038319673914955,
#  'osoba:subst niepełnosprawny:adj': 7.9853731284385585,
#  'sporządzić:ppas w:prep': 3.33854444692717,
#  'w:prep nowy:adj': -0.5722020245479792,
#  'nowy:adj jork:subst': 11.886254432183554,
#  'jork:subst dzień:subst': 7.276580177965644,
#  'wyrażać:fin się:qub': 5.737017509464087,
#  'się:qub zgoda:subst': 2.3550124611214636,
#  'zgoda:subst na:prep': 4.669667470682722,
#  'na:prep dokonać:ger': 3.6217036056848064,
#  'dokonać:ger przez:prep': 4.543098824130237,
#  'przez:prep prezydent:subst': 4.966589103773512,
#  'polski:adj ratyfikacja:subst': 8.078269653390803,
#  'życie:subst po:prep': 5.749353262401413,
#  'po:prep upływ:subst': 7.6718491885700315,
#  'dzień:subst od:prep': 4.650616500652447,
#  'od:prep dzień:subst': 5.735439707726204,
#  'marszałek:subst sejm:subst': 11.407103923177822,
#  'ewa:subst kopacz:subst': 16.62713507635314,
#  'kodeks:subst wykroczenie:subst': 6.905119789470021,
#  'wykroczenie:subst artykuł:brev': -1.9826860764825487,
#  'skreślać:fin się:qub': 6.651092345063587,
#  'na:prep teren:subst': 5.434302570876775,
#  'teren:subst las:subst': 5.043275600395228,
#  'śródleśny:adj łąka:subst': 16.86529481354791,
#  'suchy:adj łąka:subst': 13.128329219381701,
#  'łąka:subst lub:conj': 4.552159837118551,
#  'lub:conj torfowisko:subst': 3.345708959651125,
#  'albo:conj w:prep': 0.2350897819684087,
#  'w:prep odległość:subst': 2.9214115296461327,
#  'odległość:subst mały:adj': 10.54054067458178,
#  'mały:adj niż:prep': 8.868636443340492,
#  'metr:brev od:prep': 2.9295896479200647,
#  'od:prep on:ppron3': 1.9197068654379876,
#  'używać:fin ciągnik:subst': 9.946125888160953,
#  'ciągnik:subst lub:conj': 0.784994005176646,
#  'lub:conj inny:adj': 3.895384219424121,
#  'inny:adj maszyna:subst': 3.254092634975545,
#  'maszyna:subst bez:prep': 2.2738354006076844,
#  'bez:prep należyty:adj': 4.073138050370556,
#  'należyty:adj zabezpieczenie:subst': 5.038028457331193,
#  'zabezpieczenie:subst przed:prep': 4.261028201362734,
#  'przed:prep iskrzenie:subst': 9.936985234304483,
#  'rozniecać:fin ogień:subst': 18.691265413772857,
#  'ogień:subst poza:prep': 8.506390070864574,
#  'poza:prep miejsce:subst': 5.727416950176793,
#  'miejsce:subst wyznaczyć:ppas': 6.142491173737248,
#  'wyznaczyć:ppas do:prep': 2.329101701495201,
#  'do:prep ten:adj': 1.2431150097313164,
#  'ten:adj cel:subst': 3.4879860258580826,
#  'pozostawiać:fin rozniecić:ppas': 15.707753536561427,
#  'rozniecić:ppas ogień:subst': 18.691265413772857,
#  'korzystać:fin z:prep': 5.490163379462735,
#  'z:prep otwarty:adj': 1.1407317695371508,
#  'otwarty:adj płomień:subst': 14.395809530246687,
#  'wypalać:fin wierzchni:adj': 17.565734531689,
#  'wierzchni:adj warstwa:subst': 15.565734531689,
#  'warstwa:subst gleba:subst': 11.199412317443183,
#  'gleba:subst lub:conj': 4.038280434458877,
#  'lub:conj pozostałość:subst': 2.356050903872584,
#  'pozostałość:subst roślinny:adj': 8.980093839864155,
#  'porzucać:fin nie:qub': 5.355316848570562,
#  'nie:qub ugasić:ppas': 7.677244943457924,
#  'ugasić:ppas zapałka:subst': 21.150697032410157,
#  'zapałka:subst lub:conj': 5.667637054538487,
#  'lub:conj niedopałek:subst': 6.667637054538487,
#  'niedopałek:subst papieros:subst': 16.317807018245414,
#  'dopuszczać:fin się:qub': 6.109105199435669,
#  'się:qub inny:adj': -2.510295654656033,
#  'inny:adj czynność:subst': 3.7977039552537835,
#  'czynność:subst móc:pact': 2.7933136309779787,
#  'móc:pact wywołać:inf': 11.656269992416656,
#  'wywołać:inf niebezpieczeństwo:subst': 9.60380257252252,
#  'niebezpieczeństwo:subst pożar:subst': 9.298947990994098,
#  'w:prep punkt:brev': 2.169610243485964,
#  'na:prep koniec:subst': 5.670947631775373,
#  'przecinek:subst zastępować:fin': 5.4716340423460395,
#  'zastępować:fin się:qub': 6.6516456811928215,
#  'się:qub średnik:subst': 6.38958972211971,
#  'po:prep punkt:brev': 3.575155481632492,
#  'się:qub punkt:brev': 3.2498554113643654,
#  'wbrew:prep ciążyć:pact': 10.764026172772537,
#  'ciążyć:pact na:prep': 6.412210982751209,
#  'na:prep on:ppron3': 2.089456410188419,
#  'on:ppron3 obowiązek:subst': 2.494204736826171,
#  'obowiązek:subst ochrona:subst': -0.8247395449994483,
#  'ochrona:subst las:subst': 4.723471499985261,
#  'las:subst przed:prep': 4.5794332296863995,
#  'przed:prep pożar:subst': 6.129630312246879,
#  'nie:qub wykonywać:fin': 4.370450152095717,
#  'wykonywać:fin zabieg:subst': 6.403465600809795,
#  'zabieg:subst profilaktyczny:adj': 8.70400140170032,
#  'profilaktyczny:adj i:conj': 2.757173758610195,
#  'i:conj ochronny:adj': -1.6902852183610269,
#  'zapobiegać:pact powstawanie:subst': 12.788753258674914,
#  'powstawanie:subst i:conj': 2.8946772823601292,
#  'i:conj rozprzestrzeniać:ger': 3.1170697036965773,
#  'rozprzestrzeniać:ger się:qub': 6.209188239932061,
#  'się:qub pożar:subst': 3.5944783958168527,
#  'się:qub wyraz:subst': 5.659181284915681,
#  'leśny:adj lub:conj': 2.888663933850706,
#  'po:prep artykuł:brev': 2.5041024059597374,
#  'się:qub artykuł:brev': 1.4960793128672345,
#  'właściciel:subst lub:conj': 3.734188247447093,
#  'lub:conj posiadacz:subst': 2.482945342387263,
#  'posiadacz:subst las:subst': 6.853565813477379,
#  'który:adj dokonywać:fin': 2.3457653056281793,
#  'dokonywać:fin wyrąb:subst': 7.617732400711329,
#  'wyrąb:subst drzewo:subst': 12.225884528804375,
#  'drzewo:subst w:prep': -0.9106438330397958,
#  'w:prep należeć:pact': -2.2946680490190703,
#  'należeć:pact do:prep': 6.157100933468829,
#  'do:prep on:ppron3': 1.6047063650929072,
#  'on:ppron3 leś:subst': 5.881314630755575,
#  'leś:subst albo:conj': 8.477608839500792,
#  'w:prep inny:adj': 0.7097222752567348,
#  'inny:adj sposób:subst': 4.0923976957855634,
#  'sposób:subst pozyskiwać:fin': 5.6182193452913936,
#  'pozyskiwać:fin z:prep': 1.6382314290079676,
#  'z:prep ten:adj': 1.6085683439736984,
#  'ten:adj las:subst': -0.025287360451161145,
#  'las:subst drewno:subst': 8.099658070292747,
#  'niezgodnie:adv z:prep': 5.718569835824925,
#  'z:prep plan:subst': 0.9510954414670931,
#  'plan:subst urządzić:ger': 9.50984959250777,
#  'urządzić:ger las:subst': 12.47121693290471,
#  'las:subst lub:conj': 2.04705064408661,
#  'lub:conj bez:prep': 0.8680918686170427,
#  'bez:prep wymagać:ppas': 7.663314488970875,
#  'wymagać:ppas zezwolenie:subst': 6.517231957305655,
#  'podlegać:fin kara:subst': 8.094024460601606,
#  'kara:subst grzywna:subst': 8.75172095092703,
#  'w:prep raz:subst': 4.3338704848232,
#  'raz:subst popełnić:ger': 6.010772274721005,
#  'popełnić:ger wykroczenie:subst': 8.55914927862984,
#  'wykroczenie:subst określić:ppas': 3.250610183551596,
#  'określić:ppas w:prep': 4.3260182661065,
#  'orzekać:fin się:qub': 4.017977473843893,
#  'się:qub przepadek:subst': 1.9742534354232322,
#  'przepadek:subst pozyskać:ppas': 7.644699448311599,
#  'pozyskać:ppas drewno:subst': 10.314252121068787,
#  'obowiązek:subst w:prep': -1.1546287848706016,
#  'w:prep zakres:subst': 3.759448866685403,
#  'zakres:subst ochrona:subst': 3.9509121856170295,
#  'zabieg:subst zapobiegać:pact': 11.416199090717583,
#  'wykrywać:pact i:conj': 5.702032204417733,
#  'i:conj zwalczać:pact': 4.702032204417733,
#  'zwalczać:pact nadmiernie:adv': 17.450257314269063,
#  'nadmiernie:adv pojawiać:pact': 18.450257314269063,
#  'pojawiać:pact i:conj': 5.702032204417733,
#  'i:conj rozprzestrzeniać:pact': 4.702032204417733,
#  'rozprzestrzeniać:pact się:qub': 6.664867723708251,
#  'się:qub organizm:subst': 0.564731052422801,
#  'organizm:subst szkodliwy:adj': 11.000078911887337,
#  'działać:pcon bez:prep': 4.816362635008444,
#  'zmieniać:fin las:subst': 6.700387886872219,
#  'las:subst na:prep': 0.16484189588354825,
#  'na:prep uprawa:subst': 1.4191060920896101,
#  'uprawa:subst rolny:adj': 7.8185905335022525,
#  'można:pred orzec:inf': 9.802673098079831,
#  'orzec:inf obowiązek:subst': 3.905083979922738,
#  'obowiązek:subst przywrócić:ger': 4.314196645244476,
#  'przywrócić:ger do:prep': 3.0660672956614072,
#  'do:prep stan:subst': 1.149115351608786,
#  'stan:subst poprzedni:adj': 5.53938039906702,
#  'nie:qub być:pcon': 5.536382407618074,
#  'być:pcon do:prep': 3.787770594742865,
#  'do:prep to:subst': 0.5695950880228838,
#  'to:subst uprawnić:ppas': 1.7397660280159826,
#  'uprawnić:ppas albo:conj': 0.6842764843100574,
#  'albo:conj bez:prep': 1.5372011177394989,
#  'bez:prep zgoda:subst': 6.782141815035084,
#  'zgoda:subst właściciel:subst': 5.603197229641643,
#  'wjeżdżać:fin pojazd:subst': 11.747685008835159,
#  'pojazd:subst silnikowy:adj': 10.667514660151175,
#  'silnikowy:adj lub:conj': 3.62810869035185,
#  'lub:conj zaprzęgowy:adj': 4.667637054538487,
#  'zaprzęgowy:adj do:prep': 4.259839039058087,
#  'do:prep nie:qub': -5.043688048451832,
#  'nie:qub należeć:pact': 2.8602613202025426,
#  'on:ppron3 las:subst': -0.4762373738625093,
#  'las:subst w:prep': -1.4201989311029293,
#  'w:prep miejsce:subst': 1.5219001112986983,
#  'w:prep który:adj': 0.6119147699839711,
#  'który:adj być:fin': 1.8311001247308245,
#  'być:fin to:subst': 3.6388762825995937,
#  'to:subst niedozwolony:adj': 3.5558184597068014,
#  'albo:conj pozostawiać:fin': 2.619627844373221,
#  'pozostawiać:fin taki:adj': 4.33488847644884,
#  'taki:adj pojazd:subst': 0.37481994872257124,
#  'pojazd:subst w:prep': -0.7514134323937198,
#  'w:prep las:subst': 1.1033630249540833,
#  'to:subst nie:qub': 1.3129873038844357,
#  'nie:qub przeznaczyć:ppas': 1.2531699615631091,
#  'kto:subst w:prep': 0.10657380594622004,
#  'las:subst zanieczyszczać:fin': 13.208182527070916,
#  'zanieczyszczać:fin gleba:subst': 12.936377911609389,
#  'lub:conj woda:subst': 0.5780541614137782,
#  'albo:conj wyrzucać:fin': 9.062571340221949,
#  'wyrzucać:fin do:prep': 6.259839039058087,
#  'do:prep las:subst': -0.09771296555999631,
#  'las:subst kamień:subst': 9.208182527070916,
#  'padlina:subst lub:conj': 6.667637054538487,
#  'inny:adj nieczystość:subst': 5.413291229824798,
#  'sposób:subst zaśmiecać:fin': 9.705682186541733,
#  'zaśmiecać:fin las:subst': 14.208182527070916,
#  'grzywna:subst albo:conj': 4.153392568018161,
#  'albo:conj kara:subst': 3.9566628316507915,
#  'kara:subst nagana:subst': 8.37341127130037,
#  'jeżeli:comp czyn:subst': 4.752050191306543,
#  'czyn:subst sprawca:subst': 5.245041414115841,
#  'sprawca:subst polegać:fin': 4.403605496815131,
#  'polegać:fin na:prep': 6.343317838598669,
#  'na:prep zakopywać:ger': 4.522393900501632,
#  'odprowadzać:ger do:prep': 1.3529484434495689,
#  'do:prep grunt:subst': 1.8448015397792434,
#  'grunt:subst w:prep': -0.7714156288203995,
#  'lub:conj w:prep': -0.34235890137675146,
#  'sposób:subst składować:ger': 4.395826923954945,
#  'składować:ger w:prep': -0.7875396883504767,
#  'las:subst odpad:subst': 3.0533644180188118,
#  'sprawca:subst podlegać:fin': 7.178150077556624,
#  'kara:subst areszt:subst': 8.854963964958982,
#  'areszt:subst albo:conj': 5.5952128058130235,
#  'albo:conj grzywna:subst': 5.118627149857484,
#  'wykroczenie:subst określony:adj': 3.234627335812596,
#  'określony:adj w:prep': 2.419388234319605,
#  'orzec:inf nawiązka:subst': 12.640922028083219,
#  'a:conj w:prep': 2.3246560820839575,
#  'się:qub nawiązka:subst': 2.079905222987095,
#  'do:prep wysokość:subst': 2.239405446803665,
#  'wysokość:subst równy:adj': 6.062174647525486,
#  'równy:adj koszt:subst': 1.254419329043399,
#  'koszt:subst rekultywacja:subst': 5.968664846709522,
#  'rekultywacja:subst gleba:subst': 9.450951084439149,
#  'oczyszczenie:subst woda:subst': 7.694791925039631,
#  'usunięcie:subst z:prep': 3.1896413700180974,
#  'z:prep las:subst': -0.6318577343597765,
#  'a:conj także:conj': 8.861014939419793,
#  'także:conj zniszczyć:ger': 3.898955752858646,
#  'zniszczyć:ger lub:conj': 4.263246799459152,
#  'lub:conj neutralizacja:subst': 5.0826745538173315,
#  'neutralizacja:subst odpad:subst': 9.410916422636896,
#  'las:subst rozgarniać:fin': 14.208182527070916,
#  'rozgarniać:fin ściółka:subst': 18.691265413772857,
#  'ściółka:subst i:conj': 4.242600585780436,
#  'i:conj niszczyć:fin': 1.1170697036965773,
#  'niszczyć:fin grzyb:subst': 9.797550206912073,
#  'grzyb:subst lub:conj': 2.8994527297615607,
#  'lub:conj grzybnia:subst': 5.0826745538173315,
#  'las:subst wybierać:fin': 6.586130707614539,
#  'wybierać:fin jajo:subst': 10.984324696729969,
#  'jajo:subst lub:conj': 3.5383540375935207,
#  'lub:conj pisklę:subst': 5.345708959651125,
#  'niszczyć:fin lęgowisko:subst': 15.980772030967843,
#  'lęgowisko:subst lub:conj': 6.0826745538173315,
#  'lub:conj gniazdo:subst': 3.860282132480883,
#  'gniazdo:subst ptasi:adj': 17.928304611073706,
#  'albo:conj niszczyć:fin': 5.477608839500793,
#  'niszczyć:fin legowisko:subst': 14.243806436801638,
#  'nora:subst lub:conj': 4.0826745538173315,
#  'lub:conj mrowisko:subst': 5.345708959651125,
#  'ten:adj sam:adj': 7.522948205776032,
#  'sam:adj kara:subst': 6.906880260279735,
#  'kara:subst podlegać:fin': 5.498835218033202,
#  'on:ppron3 należeć:pact': 0.23425600894250556,
#  'on:ppron3 grunt:subst': 1.0257045400907492,
#  'grunt:subst rolny:adj': 8.298441693378484,
#  'niszczyć:fin mrowisko:subst': 14.243806436801638,
#  'mrowisko:subst lub:conj': 4.345708959651125,
#  'lub:conj ptasi:adj': 3.667637054538487,
#  'ptasi:adj gniazdo:subst': 16.343342110352552,
#  'czyn:subst określić:ppas': 5.557036852272054,
#  'nie:qub godzić:fin': 3.8698900214003196,
#  'godzić:fin w:prep': 3.2999231528998623,
#  'w:prep mienie:subst': 0.6594381548759329,
#  'mienie:subst społeczny:adj': 1.8573017234144933,
#  'ściganie:subst następować:fin': 9.019460156118939,
#  'następować:fin tylko:qub': 3.1895978346517655,
#  'tylko:qub na:prep': 2.4846840944483923,
#  'na:prep żądanie:subst': 5.142792010775542,
#  'żądanie:subst pokrzywdzony:subst': 8.183346921143224,
#  'w:prep sposób:subst': 2.348763756272262,
#  'sposób:subst złośliwy:adj': 7.705682186541733,
#  'płoszyć:fin albo:conj': 9.062571340221949,
#  'albo:conj ściga:subst': 9.062571340221949,
#  'rani:subst lub:conj': 6.667637054538487,
#  'lub:conj zabijać:fin': 3.345708959651125,
#  'zabijać:fin zwierzę:subst': 9.260812862107327,
#  'poza:prep czynność:subst': 0.8227574088704607,
#  'czynność:subst związać:ppas': 4.400302438029134,
#  'związać:ppas z:prep': 5.055001895511267,
#  'z:prep polowanie:subst': 1.202132314201294,
#  'polowanie:subst lub:conj': 2.7290375992026306,
#  'lub:conj ochrona:subst': -0.527567355352183,
#  'czyn:subst z:prep': -2.6608867829713088,
#  'z:prep moc:subst': 4.043870230284562,
#  'moc:subst inny:adj': -0.005498404315152538,
#  'inny:adj przepis:subst': 1.0444657108200446,
#  'przepis:subst nie:qub': -0.7875049955453663,
#  'nie:qub być:fin': 3.826803245283742,
#  'być:fin zagrozić:ppas': 4.491926416880829,
#  'zagrozić:ppas kara:subst': 7.949631290798658,
#  'kara:subst surowy:adj': 7.933757211450255,
#  'las:subst puszczać:fin': 11.886254432183554,
#  'puszczać:fin luz:subst': 15.243806436801638,
#  'luz:subst pies:subst': 11.921878341914274,
#  'prawo:subst o:prep': 1.4600405839209987,
#  'o:prep ustrój:subst': 5.775917899910708,
#  'ustrój:subst sąd:subst': 8.581343998269732,
#  'sąd:subst powszechny:adj': 7.301525109437754,
#  'powszechny:adj dział:subst': 2.4574057662206115,
#  'dział:subst i:adj': 9.2648100407127,
#  'i:adj sąd:subst': 0.16641487859060117,
#  'powszechny:adj rozdział:subst': 1.9965408789215042,
#  'przepis:subst ogólny:adj': 5.660318951214824,
#  'ogólny:adj artykuł:brev': 3.3634223947239206,
#  'powszechny:adj być:fin': 0.016215979085799425,
#  'być:fin sąd:subst': 1.2380378064211095,
#  'sąd:subst rejonowy:adj': 8.044031196454707,
#  'sąd:subst okręgowy:adj': 7.597875806392037,
#  'okręgowy:adj oraz:conj': 0.9736565553390664,
#  'oraz:conj sąd:subst': -0.8861098536499873,
#  'sąd:subst apelacyjny:adj': 8.928684674138411,
#  'powszechny:adj sprawować:fin': 3.7781210026583243,
#  'sprawować:fin wymiar:subst': 4.392725464413905,
#  'wymiar:subst sprawiedliwość:subst': 7.496225269027391,
#  'sprawiedliwość:subst w:prep': 0.7649449474651905,
#  'zakres:subst nienależący:adj': 5.646995498713985,
#  'nienależący:adj do:prep': 6.107835945613037,
#  'do:prep sąd:subst': 2.5226314022705787,
#  'sąd:subst administracyjny:adj': 6.943324263070855,
#  'sąd:subst wojskowy:adj': 5.570212333043028,
#  'wojskowy:adj oraz:conj': 2.6524261232885964,
#  'sąd:subst wysoki:adj': 6.580136890369812,
#  'powszechny:adj wykonywać:fin': 2.5206539236596854,
#  'wykonywać:fin również:qub': 4.807270702751565,
#  'również:qub zadanie:subst': 1.4783867997591125,
#  'zadanie:subst z:prep': 1.9063036227312595,
#  'z:prep zakres:subst': 2.2547272651488512,
#  'ochrona:subst prawny:adj': 3.4677657945220486,
#  'powierzyć:ppas w:prep': 0.03402909292682827,
#  'w:prep droga:subst': 4.324064848231867,
#  'droga:subst ustawa:subst': -1.7521644584205385,
#  'ilekroć:adv w:prep': 4.383609303404719,
#  'w:prep daleki:adj': 1.4519262463449125,
#  'daleki:adj przepis:subst': 3.0648109801322243,
#  'przepis:subst być:fin': -0.5557381941947587,
#  'być:fin mowa:subst': 0.746081884372783,
#  'mowa:subst o:prep': -1.0230006392987474,
#  'o:prep sąd:subst': -2.3951296416113563,
#  'sąd:subst bez:prep': -1.0314890654630569,
#  'bez:prep bliski:adj': 6.658100551091712,
#  'bliski:adj on:ppron3': 1.5214186856691916,
#  'on:ppron3 określenie:subst': 0.8166616724133209,
#  'rozumieć:fin się:qub': 6.663417049839525,
#  'się:qub przez:prep': 2.1954195080126784,
#  'przez:prep to:subst': 5.052276527323838,
#  'to:subst sąd:subst': 0.6762578995079622,
#  'zakres:subst wymiar:subst': 0.10576978891304094,
#  'sprawiedliwość:subst wykonywać:fin': 2.8147768086303557,
#  'wykonywać:fin sędzia:subst': 1.577399334324348,
#  'prawny:adj w:prep': -0.19629513599121384,
#  'w:prep sąd:subst': -0.9262659428146631,
#  'rejonowy:adj wykonywać:fin': 2.4515177302159374,
#  'wykonywać:fin także:qub': 3.369784387943424,
#  'także:qub referendarz:subst': 4.971322444866763,
#  'referendarz:subst sąd:subst': 3.9655021846646044,
#  'móc:fin wykonywać:inf': 6.939059587616961,
#  'wykonywać:inf asesor:subst': 6.412815955552377,
#  'asesor:subst sądowy:adj': 9.055810577644948,
#  'zakres:subst udzielić:ppas': 3.3666642693991595,
#  'udzielić:ppas on:ppron3': 2.423445215888561,
#  'on:ppron3 upoważnienie:subst': 2.85016593218491,
#  'sędzia:subst tworzyć:fin': 3.6744017411297403,
#  'tworzyć:fin samorząd:subst': 3.415348155171962,
#  'samorząd:subst sędziowski:adj': 6.885668089951996,
#  'organ:subst samorząd:subst': 5.5429685995898,
#  'sędziowski:adj być:fin': 2.493974245529688,
#  'zgromadzenie:subst ogólny:adj': 8.426648339713674,
#  'ogólny:adj sędzia:subst': 7.260449382963274,
#  'sędzia:subst okręg:subst': 6.75119949728573,
#  'okręg:subst oraz:conj': 0.21158589531138458,
#  'oraz:conj zgromadzenie:subst': -1.4282505230110025,
#  'sędzia:subst apelacja:subst': 8.904517978456864,
#  'w:prep sprawować:ger': 0.32729959183116797,
#  'sprawować:ger wymiar:subst': 3.2596372311519644,
#  'sprawiedliwość:subst obywatel:subst': 2.837778633991971,
#  'obywatel:subst brać:fin': 5.871666895960507,
#  'brać:fin udział:subst': 9.278483888434383,
#  'udział:subst przez:prep': -0.6638791752621094,
#  'przez:prep uczestnictwo:subst': -0.7122421968235086,
#  'uczestnictwo:subst ławnik:subst': 7.91498193764826,
#  'ławnik:subst w:prep': -0.7905673810480446,
#  'w:prep rozpoznawać:ger': -1.1215406155384142,
#  'rozpoznawać:ger sprawa:subst': 6.077870079197625,
#  'sprawa:subst przed:prep': -2.491985529133323,
#  'przed:prep sąd:subst': 4.645944994239989,
#  'sąd:subst w:prep': -1.665876258236433,
#  'w:prep pierwszy:adj': 2.054862180806328,
#  'pierwszy:adj instancja:subst': 10.433801276358441,
#  'chyba:qub że:comp': 9.958922654803363,
#  'że:comp ustawa:subst': 2.300456216157368,
#  'ustawa:subst stanowić:fin': 3.547506715066511,
#  'stanowić:fin inaczej:adv': 10.866939775839136,
#  'przy:prep rozstrzygać:ger': 6.13019448376223,
#  'rozstrzygać:ger sprawa:subst': 5.774193688866485,
#  'sprawa:subst ławnik:subst': 0.8238808129668382,
#  'ławnik:subst mieć:fin': 4.275094650076482,
#  'mieć:fin równy:adj': 3.973267761245628,
#  'równy:adj prawo:subst': 2.839834667283854,
#  'prawo:subst z:prep': 0.4910211965333698,
#  'z:prep sędzia:subst': -1.6953185855209185,
#  'język:subst urzędowy:adj': 6.902338155518629,
#  'urzędowy:adj przed:prep': -0.1858427605031838,
#  'sąd:subst być:fin': 0.12256058900117375,
#  'być:fin język:subst': 1.3240492440873752,
#  'język:subst polski:adj': 8.467609260404254,
#  'osoba:subst władać:pact': 3.505450242191865,
#  'władać:pact w:prep': -1.8175344286483142,
#  'w:prep wystarczający:adj': -0.606967442708656,
#  'wystarczający:adj stopień:subst': 6.271544588068345,
#  'stopień:subst język:subst': 3.8158651042921554,
#  'polski:adj mieć:fin': 0.47702829371850786,
#  'mieć:fin prawo:subst': 6.646295079625364,
#  'prawo:subst do:prep': 4.0334555066066935,
#  'do:prep występowanie:subst': 1.6275708235585746,
#  'występowanie:subst przed:prep': 4.5677514246387645,
#  'w:prep znać:ppas': 0.12999815145755014,
#  'znać:ppas przez:prep': 3.4032350205964272,
#  'przez:prep on:ppron3': 3.298484615642259,
#  'on:ppron3 języku:subst': 7.466277131476731,
#  'języku:subst i:conj': 4.702032204417733,
#  'i:conj bezpłatny:adj': -0.1806108449441077,
#  'bezpłatny:adj korzystać:ger': 4.964558606257937,
#  'korzystać:ger z:prep': 5.510655896954157,
#  'z:prep pomoc:subst': 1.439235518913183,
#  'pomoc:subst tłumacz:subst': 5.734955264120065,
#  'o:prep przyznać:ger': 5.278633012285284,
#  'przyznać:ger tłumacz:subst': 8.359534143855138,
#  'tłumacz:subst osoba:subst': 2.2603377443553336,
#  'orzekać:fin sąd:subst': 5.758934730489839,
#  'sąd:subst właściwy:adj': 1.9889777545934482,
#  'właściwy:adj do:prep': 5.543815748075202,
#  'do:prep rozpoznać:ger': 4.956911906100781,
#  'rozpoznać:ger sprawa:subst': 6.962734368476145,
#  'sprawa:subst w:prep': -2.099300267143891,
#  'wniosek:subst o:prep': 4.456127018320654,
#  'tłumacz:subst zgłosić:ppas': 7.327329792363921,
#  'zgłosić:ppas w:prep': 1.5569293293176478,
#  'w:prep tok:subst': 4.339608733350034,
#  'tok:subst sprawa:subst': 1.1825674578643184,
#  'sprawa:subst rozpoznawać:fin': 4.148079081479028,
#  'rozpoznawać:fin sąd:subst': 6.250030307746773,
#  'sąd:subst ten:adj': -1.3387092942204992,
#  'ten:adj instancja:subst': 0.6411027396138413,
#  'który:adj sprawa:subst': -2.284950446336638,
#  'sprawa:subst się:qub': -3.541710618393107,
#  'się:qub toczyć:fin': 3.1146706411477716,
#  'osoba:subst pozostawać:pact': 5.963720737997159,
#  'pozostawać:pact z:prep': 2.971604498300892,
#  'z:prep siebie:siebie': 3.0284287999123585,
#  'siebie:siebie w:prep': 0.017695181832758155,
#  'w:prep stosunek:subst': 3.583537931406756,
#  'stosunek:subst pokrewieństwo:subst': 9.782861419986823,
#  'pokrewieństwo:subst w:prep': 0.5526892232798293,
#  'w:prep linia:subst': 1.5388036970248795,
#  'linia:subst prosty:adj': 13.12279103584027,
#  'prosty:adj lub:conj': 2.9127495523750184,
#  'lub:conj powinowactwo:subst': 6.5456465301598765,
#  'powinowactwo:subst w:prep': 2.772293827244658,
#  'prosty:adj albo:conj': 4.30768383805848,
#  'stosunek:subst przysposobienie:subst': 8.715651002762932,
#  'małżonek:subst oraz:conj': 2.3765304553827753,
#  'oraz:conj rodzeństwo:subst': 1.9461449917704954,
#  'rodzeństwo:subst nie:qub': 3.0922824427367677,
#  'nie:qub móc:fin': 5.081785339691822,
#  'móc:fin być:inf': 7.783835705643047,
#  'być:inf sędzia:subst': 1.735330739772072,
#  'sądowy:adj ani:conj': 3.8803423858155406,
#  'ani:conj referendarz:subst': 7.177044504414729,
#  'referendarz:subst sądowy:adj': 11.177717246343864,
#  'sądowy:adj w:prep': 0.43973826098996927,
#  'w:prep ten:adj': 1.7281571485330796,
#  'sam:adj wydział:subst': 4.553997693242761,
#  'wydział:subst sąd:subst': 3.075379802436978,
#  'nadzór:subst nad:prep': 9.941908195028432,
#  'nad:prep działalność:subst': 6.0519075743322315,
#  'działalność:subst sąd:subst': 0.796549022289617,
#  'zakres:subst orzekać:ger': 4.86656187597167,
#  'orzekać:ger sprawować:fin': 6.651017210943351,
#  'sprawować:fin sąd:subst': 2.884465612573698,
#  'w:prep tryb:subst': 2.8491448460219932,
#  'tryb:subst określony:adj': 4.400338035209827,
#  'określony:adj ustawa:subst': 1.6565053429541647,
#  'działalność:subst administracyjny:adj': 3.3627562233391037,
#  'administracyjny:adj sąd:subst': 2.9681276540714276,
#  'sąd:subst mieć:fin': 0.21656394883232258,
#  'mieć:fin na:prep': 1.4515275697819876,
#  'cel:subst zapewnić:ger': 7.405087343834698,
#  'zapewnić:ger sąd:subst': -0.39064162556067056,
#  'sąd:subst odpowiedni:adj': 0.14447232570992416,
#  'odpowiedni:adj warunki:subst': 4.650354416390977,
#  'warunki:subst wykonywać:ger': 4.265823889082576,
#  'wykonywać:ger on:ppron3': 1.125220104852266,
#  'on:ppron3 zadanie:subst': 2.9290883005214345,
#  'sąd:subst należeć:fin': -0.922672802386495,
#  'należeć:fin do:prep': 2.8843123479122537,
#  'do:prep organ:subst': 0.3525688368059132,
#  'organ:subst sąd:subst': -0.475450013365032,
#  'sąd:subst oraz:conj': -0.4140414093347644,
#  'oraz:conj do:prep': -0.5556194796770989,
#  'do:prep urzędnik:subst': 1.386394926542711,
#  'czynność:subst z:prep': -0.3512808199153315,
#  'zakres:subst działalność:subst': 3.2202445788713514,
#  'należeć:fin także:qub': 4.475464880594424,
#  'także:qub do:prep': 2.129462104425763,
#  'do:prep sędzia:subst': 0.2311436060576218,
#  'jeżeli:comp to:subst': 0.33928215849361854,
#  'to:subst wynikać:fin': 3.269959619526961,
#  'wynikać:fin z:prep': 4.646879887081479,
#  'z:prep przepis:subst': 1.6184963358731008,
#  'przepis:subst prawo:subst': 4.530503835067203,
#  'zwierzchni:adj nadzór:subst': 10.271726522259074,
#  'sąd:subst sprawować:fin': 1.299503111852542,
#  'sprawować:fin minister:subst': 5.477528305449891,
#  'minister:subst sprawiedliwość:subst': 7.952476340794537,
#  'sprawiedliwość:subst osobiście:adv': 5.77723709205692,
#  'osobiście:adv oraz:conj': 1.9262454343327904,
#  'oraz:conj przez:prep': -0.9911470823785747,
#  'przez:prep właściwy:adj': 2.454981942113927,
#  'właściwy:adj służba:subst': 0.9312598654340648,
#  'służba:subst nadzór:subst': -1.6199708927902527,
#  'podstawowy:adj zadanie:subst': 4.116023217911562,
#  'zakres:subst zwierzchni:adj': 4.5094919749640505,
#  'sąd:subst bezpośrednio:adv': 0.5576962546168368,
#  'bezpośrednio:adv związany:adj': 6.591806590371072,
#  'związany:adj z:prep': 5.685489179230475,
#  'z:prep wykonywać:ger': 1.6568123033241058,
#  'wykonywać:ger wymiar:subst': -0.521119348985613,
#  'sprawiedliwość:subst być:fin': 0.04730445822267539,
#  'być:fin wykonywać:ppas': 4.6118203282426755,
#  'wykonywać:ppas przez:prep': 5.718690981688887,
#  'przez:prep sędzia:subst': 2.544464589038274,
#  'sędzia:subst delegować:ppas': 9.144721675909773,
#  'delegować:ppas do:prep': 4.5817671339454495,
#  'do:prep ministerstwo:subst': 1.8004074204207898,
#  'ministerstwo:subst sprawiedliwość:subst': 9.537377375693692,
#  'tryb:subst określić:ppas': 5.489977924674136,
#  'organizacja:subst sąd:subst': -0.13614789142982994,
#  'sąd:subst artykuł:brev': -2.9894178771465025,
#  'rejonowy:adj tworzyć:fin': 5.548520137021329,
#  'tworzyć:fin się:qub': 5.828753808669223,
#  'się:qub dla:prep': -0.5890706482947042,
#  'dla:prep jeden:adj': 2.3645798615815448,
#  'jeden:adj lub:conj': 2.5262134747213087,
#  'lub:conj duży:adj': 3.312432804776826,
#  'duży:adj liczba:subst': 8.386968069917716,
#  'liczba:subst gmina:subst': 1.0933054648321068,
#  'w:prep uzasadniony:adj': 2.507742773149038,
#  'uzasadniony:adj przypadek:subst': 7.3904745704971555,
#  'przypadek:subst móc:fin': -1.3898920834618922,
#  'być:inf utworzyć:ppas': 5.356368203859291,
#  'utworzyć:ppas więcej:num': 5.019804762603532,
#  'więcej:num niż:prep': 6.717727265745685,
#  'niż:prep jeden:adj': 5.299367223367712,
#  'jeden:adj sąd:subst': 2.1510776892822103,
#  'rejonowy:adj w:prep': -0.8546538842090134,
#  'w:prep obręb:subst': 4.09700973950364,
#  'obręb:subst ten:adj': 2.9476007939315974,
#  'sam:adj gmina:subst': 1.731891159625687,
#  'okręgowy:adj tworzyć:fin': 4.3091449692605,
#  'dla:prep obszar:subst': 3.54256348285312,
#  'obszar:subst właściwość:subst': 7.0232583691866886,
#  'właściwość:subst co:prep': 3.578679669294292,
#  'co:prep mało:adv': 10.57813127268386,
#  'mało:adv dwa:num': 7.488400259442617,
#  'dwa:num sąd:subst': 1.287430279551967,
#  'zwać:ppas daleko:adv': 11.539480021047604,
#  'okrąg:subst sądowy:adj': 6.2328588005363255,
#  'apelacyjny:adj tworzyć:fin': 6.716036229837704,
#  'dwa:num okręg:subst': 3.0173942440128516,
#  'okręg:subst sądowy:adj': 6.791081453305061,
#  'obszar:subst apelacja:subst': 6.917915799344296,
#  'sąd:subst dzielić:fin': 2.7513773793117573,
#  'dzielić:fin się:qub': 6.5438523227468846,
#  'się:qub na:prep': 1.6438949055493381,
#  'na:prep wydział:subst': 2.4034528277781244,
#  'wydział:subst kierować:fin': 6.4619003513557,
#  'kierować:fin przewodniczący:subst': 6.497932069115703,
#  'przewodniczący:subst wydział:subst': 8.463419777552902,
#  'być:fin prezes:subst': 1.4654965449535546,
#  'prezes:subst albo:conj': -0.43156993270299543,
#  'albo:conj wiceprezes:subst': 4.12711159241666,
#  'wiceprezes:subst sąd:subst': 7.146386398096784,
#  'sąd:subst lub:conj': 1.7556550166472702,
#  'inny:adj sędzia:subst': 0.1622033754878855,
#  'funkcja:subst przewodniczyć:pact': 7.7543347497939585,
#  'przewodniczyć:pact wydział:subst': 11.17830462303959,
#  'wydział:subst w:prep': -0.2746974035998345,
#  'apelacyjny:adj i:conj': 1.7149712601252318,
#  'i:conj okręgowy:adj': -0.3293499210672637,
#  'okręgowy:adj powierzać:fin': 5.955036468623988,
#  'powierzać:fin sędzia:subst': 6.320293240493228,
#  'sędzia:subst prezes:subst': 0.42818798164838107,
#  'prezes:subst ten:adj': 0.008048372684290008,
#  'ten:adj sąd:subst': 1.6190624703902032,
#  'na:prep wniosek:subst': 4.715123000169737,
#  'wniosek:subst prezes:subst': 4.000766939000272,
#  'prezes:subst przełożony:adj': 6.829301279989902,
#  'przełożony:adj sąd:subst': 6.811851238338073,
#  'przed:prep powierzyć:ger': 4.597135231419858,
#  'powierzyć:ger funkcja:subst': 7.727367702193689,
#  'wydział:subst prezes:subst': 3.7302597647040994,
#  'prezes:subst zasięgać:fin': 6.456883414648846,
#  'zasięgać:fin opinia:subst': 10.54390380188604,
#  'opinia:subst właściwy:adj': 3.6825596163463374,
#  'właściwy:adj kolegium:subst': 2.513001827262105,
#  'kolegium:subst sąd:subst': 5.84967270377304,
#  'sam:adj tryb:subst': 3.367052405582426,
#  'tryb:subst prezes:subst': -2.157125241097327,
#  'prezes:subst sąd:subst': 6.014358197517969,
#  'sąd:subst zwalniać:fin': 2.860420138607047,
#  'zwalniać:fin sędzia:subst': 3.8108209393563355,
#  'sędzia:subst z:prep': -0.30300116274215844,
#  'z:prep funkcja:subst': -0.10985754362994914,
#  'funkcja:subst przewodniczący:subst': 5.498881522944567,
#  'rejonowy:adj dzielić:fin': 6.160859076673791,
#  'do:prep sprawa:subst': 5.3356872632531225,
#  'sprawa:subst z:prep': -0.6300275111488602,
#  'zakres:subst prawo:subst': 2.281199694660835,
#  'prawo:subst cywilny:adj': 3.477106666051154,
#  'prawo:subst karny:adj': 1.1052264184801939,
#  'w:prep to:subst': 3.0081920842718435,
#  'to:subst do:prep': -0.9362958417070737,
#  'sprawa:subst o:prep': 1.7660206260079436,
#  'o:prep wykroczenie:subst': 4.3434060481030246,
#  'wykroczenie:subst rozpoznawać:ppas': 7.370977677266752,
#  'rozpoznawać:ppas w:prep': 3.5223155742363104,
#  'w:prep drugi:adj': 0.8931345392650407,
#  'drugi:adj instancja:subst': 10.219080315048801,
#  'rodzinny:adj i:conj': 2.6474595819891102,
#  'i:conj nieletni:subst': 0.9364974580547567,
#  'sąd:subst rodzinny:adj': 3.7202093612180778,
#  'prawo:subst rodzinny:adj': 0.5653954981778104,
#  'i:conj opiekuńczy:adj': 3.398482638845226,
#  'dotyczyć:pact demoralizacja:subst': 6.183786082293785,
#  'demoralizacja:subst i:conj': 2.795141608809215,
#  'i:conj czyn:subst': -4.269511349533039,
#  'czyn:subst karalny:adj': 10.825516523844684,
#  'karalny:adj nieletni:adj': 11.398316385857262,
#  'dotyczyć:pact leczyć:ger': 4.159939340339417,
#  'leczyć:ger osoba:subst': 2.3296004067924474,
#  'osoba:subst uzależnić:ppas': 6.086086817510231,
#  'uzależnić:ppas od:prep': 7.398853692620055,
#  'od:prep alkohol:subst': 4.78265515263352,
#  'alkohol:subst oraz:conj': 2.3758292670137404,
#  'oraz:conj od:prep': -0.7605334173503533,
#  'od:prep środek:subst': 1.4315745467363927,
#  'środek:subst odurzający:adj': 9.145555810341719,
#  'odurzający:adj i:conj': 2.5321072029754212,
#  'i:conj psychotropowy:adj': -0.04392217297572725,
#  'sąd:subst opiekuńczy:adj': 6.996381497548577,
#  'opiekuńczy:adj na:prep': -0.4999739125268226,
#  'na:prep podstawa:subst': 6.153599003370843,
#  'podstawa:subst odrębny:adj': 6.919704292934957,
#  'odrębny:adj ustawa:subst': 4.489955692504353,
#  'sąd:subst praca:subst': 1.9044460744604155,
#  'prawo:subst praca:subst': 2.4978250610096087,
#  'księga:subst wieczysty:adj': 11.283187617951116,
#  'do:prep prowadzić:ger': 3.402697412718372,
#  'prowadzić:ger księga:subst': 7.307757473125021,
#  'wieczysty:adj oraz:conj': 2.262834709735886,
#  'do:prep inny:adj': 0.8008826946932122,
#  'inny:adj sprawa:subst': 0.8172104805517347,
#  'sprawa:subst cywilny:adj': 2.6518421748598464,
#  'cywilny:adj z:prep': -0.9080907090475228,
#  'zakres:subst postępowanie:subst': 0.7998933977703598,
#  'postępowanie:subst wieczystoksięgowego:adj': 9.174311914521564,
#  'rejonowy:adj mieć:pact': 3.7783137217396807,
#  'mieć:pact siedziba:subst': 8.654415771398787,
#  'siedziba:subst w:prep': 0.7472732020110988,
#  'w:prep miasto:subst': 1.2092734425805365,
#  'miasto:subst być:pact': 6.037058289796525,
#  'być:pact siedziba:subst': 5.512198025388511,
#  'siedziba:subst sąd:subst': 3.3149418431205384,
#  'być:fin utworzyć:ppas': -1.1133560682199233,
#  'utworzyć:ppas wydział:subst': 7.59435064737935,
#  'wydział:subst ubezpieczenie:subst': 4.029644183206797,
#  'ubezpieczenie:subst społeczny:adj': 8.92490367800652,
#  'społeczny:adj albo:conj': 2.103728664978709,
#  'albo:conj wydział:subst': 5.113555268940754,
#  'wydział:subst praca:subst': 3.7418811589865784,
#  'praca:subst i:conj': 1.7363379503364045,
#  'i:conj ubezpieczenie:subst': -0.46718955789737693,
#  'miejsce:subst wydział:subst': 3.2697892643045567,
#  'się:qub wydział:subst': 1.5459266509847436,
#  'społeczny:adj do:prep': -1.2135768090149108,
#  'praca:subst oraz:conj': 2.088290037882917,
#  'zakres:subst ubezpieczenie:subst': 2.7741667391791003,
#  'do:prep właściwość:subst': 3.7007735074472174,
#  'właściwość:subst sąd:subst': 5.568912848720919,
#  'sam:adj okręg:subst': 5.7684546680648445,
#  'okręgowy:adj lub:conj': 0.2736848496687816,
#  'miasto:subst na:prep': 4.041797671866293,
#  'na:prep prawo:subst': 1.0185341939613055,
#  'prawo:subst powiat:subst': 5.762258747066724,
#  'powiat:subst tworzyć:fin': 4.4229892549374705,
#  'wydział:subst gospodarczy:adj': 5.415207115907659,
#  'gospodarczy:adj albo:conj': 2.253377418500564,
#  'sąd:subst gospodarczy:adj': 1.9700894541602565,
#  'prawo:subst gospodarczy:adj': -0.5181481426052024,
#  'gospodarczy:adj i:conj': 1.2851557054751086,
#  'i:conj cywilny:adj': -2.1333866360577467,
#  'powierzyć:ppas sąd:subst': 2.536109392408691,
#  'sprawa:subst gospodarczy:adj': 0.5202149244722042,
#  'do:prep orzekać:ger': 4.27946784580702,
#  'orzekać:ger w:prep': 3.2866873257431686,
#  'w:prep jednostka:subst': 0.15828719588897364,
#  'wyznaczać:fin się:qub': 3.907068626124879,
#  'się:qub sędzia:subst': -0.4342170371836124,
#  'sędzia:subst i:conj': 1.5848000968156106,
#  'i:conj ławnik:subst': 1.8485808677706754,
#  'ławnik:subst wykazywać:pact': 11.963344959209659,
#  'wykazywać:pact szczególny:adj': 9.41514100849862,
#  'szczególny:adj znajomość:subst': 8.020149451421535,
#  'znajomość:subst problematyka:subst': 12.673343505775597,
#  'problematyka:subst sprawa:subst': 3.6773321496138967,
#  'sprawa:subst pracowniczy:adj': 2.8513615493889453,
#  'a:conj do:prep': -2.0285945077350163,
#  'także:qub sędzia:subst': 2.364090780304574,
#  'znajomość:subst cel:subst': 3.364797622808981,
#  'cel:subst ubezpieczenie:subst': 0.8724608506560662,
#  'ubezpieczenie:subst i:conj': -0.8406479534248213,
#  'i:conj potrzeba:subst': -0.5953825321464947,
#  'potrzeba:subst osoba:subst': 1.1398007698751846,
#  'osoba:subst ubezpieczyć:ppas': 5.812878767384112,
#  'sędzia:subst wykazywać:pact': 8.855215058714789,
#  'problematyka:subst gospodarczy:adj': 6.074716569993869,
#  'rejonowy:adj móc:fin': 1.845671912409516,
#  'być:inf tworzyć:ppas': 7.664490499221623,
#  'w:prep on:ppron3': -0.22988957472872926,
#  'on:ppron3 siedziba:subst': 4.037559508446348,
#  'siedziba:subst lub:conj': 3.290758363027723,
#  'lub:conj poza:prep': 0.8750791344089637,
#  'poza:prep on:ppron3': 2.981841506709539,
#  'sąd:subst grodzki:adj': 9.194320875160486,
#  'grodzki:adj jako:conj': 8.815865104292156,
#  'jako:conj wydział:subst': 5.504278953626253,
#  'wydział:subst lub:conj': 1.870624076702342,
#  'lub:conj wydział:subst': 2.356050903872584,
#  'wydział:subst zamiejscowy:adj': 13.288531375048759,
#  'zamiejscowy:adj sąd:subst': 6.512496835186741,
#  'grodzki:adj powierzać:fin': 13.93395117421485,
#  'powierzać:fin się:qub': 4.840439288291705,
#  'się:qub rozpoznawać:ger': -0.5639509667876301,
#  'wykroczenie:subst w:prep': -0.4500488588494894,
#  'wykroczenie:subst skarbowy:adj': 9.108582905689008,
#  'skarbowy:adj i:conj': 1.1480829869961464,
#  'i:conj przestępstwo:subst': -1.506771152170759,
#  'przestępstwo:subst skarbowy:adj': 8.657642594514881,
#  'skarbowy:adj zagrozić:ppas': 6.1352683677024125,
#  'grzywna:subst do:prep': 3.713230346239007,
#  'stawka:subst dzienny:adj': 11.214059093407585,
#  'dzienny:adj lub:conj': 1.345708959651125,
#  'lub:conj zagrozić:ppas': 2.2505517266107846,
#  'kara:subst ograniczyć:ger': 8.986262447232543,
#  'ograniczyć:ger wolność:subst': 10.481630220826187,
#  'wolność:subst albo:conj': 6.493327073247723,
#  'kara:subst pozbawienie:subst': 8.683020164419846,
#  'pozbawienie:subst wolność:subst': 10.94087757968922,
#  'wolność:subst do:prep': 4.159335438573255,
#  'do:prep rok:subst': 2.6177920605655767,
#  'o:prep przestępstwo:subst': 3.2080532497146463,
#  'przestępstwo:subst ścigać:ppas': 9.647398811057412,
#  'ścigać:ppas z:prep': 4.762975286337767,
#  'z:prep oskarżenie:subst': 4.389410882393874,
#  'oskarżenie:subst prywatny:adj': 11.765504044064777,
#  'wyjątek:subst sprawa:subst': 2.810742918729948,
#  'sprawa:subst podlegać:pact': 2.893399342557533,
#  'podlegać:pact rozpoznać:ger': 6.219082297583317,
#  'rozpoznać:ger z:prep': -1.3186998491001465,
#  'z:prep udział:subst': 2.204862106956867,
#  'udział:subst ławnik:subst': 4.793419957767347,
#  'o:prep pozostały:adj': -1.230882866466131,
#  'pozostały:adj przestępstwo:subst': 2.220153621608616,
#  'podlegać:pact rozpoznanie:subst': 6.733655470413075,
#  'rozpoznanie:subst w:prep': 1.0628839555990133,
#  'w:prep postępowanie:subst': 1.634718695064625,
#  'postępowanie:subst uprościć:ppas': 6.497851059314911,
#  'cywilny:adj podlegać:pact': 1.1061294815789282,
#  'rozpoznać:ger w:prep': -0.06264692648484578,
#  'uprościć:ppas oraz:conj': -0.3677457840514487,
#  'oraz:conj dotyczyć:pact': -0.943950361295045,
#  'dotyczyć:pact depozyt:subst': 2.685535214765959,
#  'depozyt:subst sądowy:adj': 8.50543697904099,
#  'sądowy:adj i:conj': 2.119025900661904,
#  'i:conj przepadek:subst': -3.0760449251176247,
#  'przepadek:subst rzecz:subst': 6.276846148120082,
#  'grodzki:adj tworzyć:fin': 10.288059674851361,
#  'tworzyć:fin i:conj': 2.4281094824412035,
#  'i:conj znosić:fin': 5.027432491211901,
#  'znosić:fin minister:subst': 3.4123441366897533,
#  'droga:subst rozporządzenie:subst': 8.724894480231184,
#  'w:prep rozporządzenie:subst': 0.3887357901404943,
#  'rozporządzenie:subst o:prep': -1.2629919658060094,
#  'o:prep utworzyć:ger': 4.384029021629646,
#  'utworzyć:ger sąd:subst': 0.19996743830162766,
#  'grodzki:adj należeć:fin': 9.22634843280557,
#  'należeć:fin określić:inf': 6.329001609867923,
#  'określić:inf on:ppron3': 2.453453091119147,
#  'właściwość:subst w:prep': -2.1905552934535946,
#  'w:prep granica:subst': 1.846550136506842,
#  'granica:subst obszar:subst': 4.507310546380713,
#  'rejonowy:adj oraz:conj': 1.3765304553827753,
#  'oraz:conj zakres:subst': 1.2010830950989013,
#  'zakres:subst sprawa:subst': 0.7098778316058545,
#  'sprawa:subst przekazać:ppas': 3.6403379421316946,
#  'przekazać:ppas do:prep': 3.541020791602141,
#  'do:prep rozpoznawać:ger': 3.554582304619219,
#  'rozpoznawać:ger sąd:subst': 1.9655021846646046,
#  'spośród:prep sprawa:subst': 1.3845504003860503,
#  'sprawa:subst wymienić:ppas': 1.0822563502496463,
#  'wymienić:ppas w:prep': 4.044157526651211,
#  'przy:prep tworzyć:ger': 5.083594070900091,
#  'tworzyć:ger i:conj': 3.712575698659203,
#  'i:conj znosić:ger': 4.871957205860046,
#  'znosić:ger sąd:subst': 4.194320875160486,
#  'należeć:fin kierować:inf': 7.261113850966248,
#  'kierować:inf się:qub': 5.62924381397753,
#  'się:qub ilość:subst': -0.646880591296708,
#  'ilość:subst sprawa:subst': -0.17498454675376537,
#  'sprawa:subst wpływać:pact': 4.114395955222739,
#  'wpływać:pact do:prep': 2.559399320916995,
#  'oraz:conj wzgląd:subst': -1.1243806387371773,
#  'wzgląd:subst ekonomia:subst': 8.780963383515203,
#  'ekonomia:subst postępowanie:subst': 7.267421318913045,
#  'postępowanie:subst sądowy:adj': 5.506772100554066,
#  'sprawiedliwość:subst móc:fin': 4.48194948523035,
#  'móc:fin tworzyć:inf': 7.829630177905996,
#  'tworzyć:inf poza:prep': 7.26538197136078,
#  'poza:prep siedziba:subst': 6.037533056980978,
#  'rejonowy:adj inny:adj': 0.03632177137947455,
#  'inny:adj wydział:subst': 1.464275158543604,
#  'raz:subst znieść:ger': 7.32986081708583,
#  'znieść:ger wydział:subst': 8.55602252872025,
#  'rejonowy:adj pracownik:subst': 0.6268805046714395,
#  'pracownik:subst zatrudnić:ppas': 8.260542842076731,
#  'zatrudnić:ppas w:prep': 3.557322024064224,
#  'w:prep znieść:ppas': -0.17812414390478148,
#  'znieść:ppas jednostka:subst': 5.3997284087385085,
#  'jednostka:subst przechodzić:fin': 1.7692512487649836,
#  'przechodzić:fin do:prep': 3.572778350718195,
#  'do:prep odpowiedni:adj': 1.2099904896075258,
#  'odpowiedni:adj sąd:subst': 2.366864747046372,
#  'okręgowy:adj dzielić:fin': 4.921483908912962,
#  'rozpoznawać:ger w:prep': -1.1215406155384142,
#  'instancja:subst sprawa:subst': 1.860639362976956,
#  'cywilny:adj i:conj': 1.9197247004018159,
#  'i:conj rodzinny:adj': 0.07591759703027597,
#  'rodzinny:adj oraz:conj': 1.9049928851041937,
#  'cywilny:adj oraz:conj': 2.2806511527373274,
#  'oraz:conj sprawa:subst': -1.8978632709461543,
#  'sprawa:subst należeć:pact': 5.6235608931729155,
#  'sprawa:subst przeciwko:prep': 1.6244465693618035,
#  'przeciwko:prep nieletni:subst': 6.743562070212822,
#  'nieletni:subst o:prep': 0.08146625160921415,
#  'o:prep popełnić:ger': 3.003463739607941,
#  'popełnić:ger czyn:subst': 9.443675965952586,
#  'jeżeli:comp wobec:prep': 1.8165323861946239,
#  'wobec:prep nieletni:adj': 7.684668381159253,
#  'nieletni:adj zastosować:imps': 10.462446723276978,
#  'zastosować:imps środek:subst': 7.035019334192053,
#  'środek:subst poprawczy:adj': 5.895682652583163,
#  'poprawczy:adj lub:conj': 3.597247726647089,
#  'lub:conj gdy:adv': 1.4611861770710608,
#  'gdy:adv środek:subst': 2.2042317176693254,
#  'środek:subst odwoławczy:adj': 6.747770203829932,
#  'odwoławczy:adj zawierać:fin': 4.1403656233929755,
#  'zawierać:fin wniosek:subst': 1.291931724965641,
#  'o:prep orzec:ger': 2.2580365666935385,
#  'orzec:ger środek:subst': 5.484022753112421,
#  'karny:adj w:prep': -0.46710657359617486,
#  'pierwszy:adj i:conj': 0.5167220397692496,
#  'i:conj drugi:adj': 1.019739832986901,
#  'instancja:subst oraz:conj': 1.009870589380883,
#  'sprawa:subst rozpoznawać:ppas': 6.72172626897235,
#  'instancja:subst przeciwko:prep': 3.5549005061889236,
#  'o:prep popełnieć:ger': 4.3615741708019495,
#  'popełnieć:ger czyn:subst': 10.956761057122936,
#  'wobec:prep nieletni:subst': 7.826024230404795,
#  'nieletni:subst zastosować:imps': 9.60380257252252,
#  'penitencjarny:adj i:conj': 0.22629877345133573,
#  'i:conj nadzór:subst': 0.504885734240397,
#  'nad:prep wykonywać:ger': 4.19998414268385,
#  'wykonywać:ger orzeczenie:subst': 3.7161516996682287,
#  'orzeczenie:subst karny:adj': 2.1982162599569057,
#  'sprawa:subst penitencjarny:adj': 1.6610303372847957,
#  'nad:prep sądowy:adj': 0.9912728139665671,
#  'sądowy:adj postępowanie:subst': 1.456146027484098,
#  'postępowanie:subst wykonawczy:adj': 4.902507299060038,
#  'wykonawczy:adj w:prep': -0.5220785451221429,
#  'w:prep sprawa:subst': 2.644091596181748,
#  'oraz:conj wydział:subst': 3.5820914212104564,
#  'sąd:subst ubezpieczenie:subst': -2.8077909013193665,
#  ...}

# %% [markdown]
# 11. Compute trigram counts for both corpora and perform the same filtering.

# %% [markdown]
# ### Trigrams

# %%
trigram_counts = collections.defaultdict(int)

for file, tokens in text_tokenized.items():
    for trigram, count in count_ngrams(tokens, n=3).items():
        trigram_counts[trigram] += count

# %%
sorted(trigram_counts.items(), key=lambda trigram_count: -trigram_count[1])[:20]
# Out:
# [(', poz .', 43166),
#  ('- - -', 34646),
#  ('w art .', 32032),
#  ('w ust .', 23520),
#  ('ust . 1', 23324),
#  ('. art .', 22917),
#  ('r . nr', 17860),
#  ('_ _ _', 16213),
#  ('. 1 .', 15635),
#  ('. 2 .', 15282),
#  ('o których mowa', 13856),
#  ('których mowa w', 13806),
#  (', o których', 13774),
#  ('mowa w ust', 13474),
#  (': 1 )', 13465),
#  ('mowa w art', 12311),
#  (') w art', 11719),
#  ('ust . 2', 10746),
#  ('. 3 .', 9673),
#  ('otrzymuje brzmienie :', 9505)]

# %%
trigram_counts = {
    trigram: count
    for (trigram, count)
    in trigram_counts.items()
    if all([token.isalpha() for token in trigram.split(' ')])
}

# %%
sorted(trigram_counts.items(), key=lambda trigram_count: -trigram_count[1])[:20]
# Out:
# [('o których mowa', 13856),
#  ('których mowa w', 13806),
#  ('mowa w ust', 13474),
#  ('mowa w art', 12311),
#  ('o którym mowa', 9169),
#  ('którym mowa w', 9147),
#  ('o której mowa', 5510),
#  ('której mowa w', 5487),
#  ('w drodze rozporządzenia', 4685),
#  ('właściwy do spraw', 4620),
#  ('minister właściwy do', 4600),
#  ('ustawie z dnia', 3649),
#  ('w ustawie z', 3645),
#  ('stosuje się odpowiednio', 3089),
#  ('ustawy z dnia', 3053),
#  ('zastępuje się wyrazami', 2940),
#  ('dodaje się ust', 2766),
#  ('wejścia w życie', 2353),
#  ('dni od dnia', 2070),
#  ('się następujące zmiany', 1806)]

# %% [markdown]
# ### Lemmatized Trigrams

# %%
lemmatized_trigram_counts = collections.defaultdict(int)

for file, tokens in lemmatized_acts.items():
    for trigram, count in count_ngrams(tokens, n=3).items():
        lemmatized_trigram_counts[trigram] += count

# %%
sorted(lemmatized_trigram_counts.items(), key=lambda trigram_count: -trigram_count[1])[:20]
# Out:
# [(',:interp pozycja:brev .:interp', 43168),
#  ('-:interp -:interp -:interp', 34646),
#  ('w:prep artykuł:brev .:interp', 32031),
#  ('o:prep który:adj mowa:subst', 28535),
#  (',:interp o:prep który:adj', 28455),
#  ('który:adj mowa:subst w:prep', 28442),
#  ('w:prep ustęp:brev .:interp', 23520),
#  ('ustęp:brev .:interp 1:adj', 23310),
#  ('.:interp artykuł:brev .:interp', 22917),
#  ('rok:brev .:interp numer:brev', 17860),
#  ('.:interp .:interp .:interp', 17153),
#  ('_:interp _:interp _:interp', 16213),
#  ('.:interp 1:adj .:interp', 15643),
#  ('.:interp 2:adj .:interp', 15280),
#  ('::interp 1:adj ):interp', 13489),
#  ('mowa:subst w:prep ustęp:brev', 13462),
#  ('brzmienie:subst ::interp ":interp', 12499),
#  ('mowa:subst w:prep artykuł:brev', 12307),
#  ('):interp w:prep artykuł:brev', 12052),
#  ('ustęp:brev .:interp 2:adj', 10502)]

# %%
lemmatized_trigram_counts = {
    trigram: count
    for (trigram, count)
    in lemmatized_trigram_counts.items()
    if all([token.split(':')[0].isalpha() and token != 'X:X' for token in trigram.split(' ')])
}

# %%
sorted(lemmatized_trigram_counts.items(), key=lambda trigram_count: -trigram_count[1])[:20]
# Out:
# [('o:prep który:adj mowa:subst', 28535),
#  ('który:adj mowa:subst w:prep', 28442),
#  ('mowa:subst w:prep ustęp:brev', 13462),
#  ('mowa:subst w:prep artykuł:brev', 12307),
#  ('ustawa:subst z:prep dzień:subst', 8589),
#  ('właściwy:adj do:prep sprawa:subst', 7966),
#  ('minister:subst właściwy:adj do:prep', 7888),
#  ('w:prep droga:subst rozporządzenie:subst', 4748),
#  ('zastępować:fin się:qub wyraz:subst', 3653),
#  ('w:prep ustawa:subst z:prep', 3646),
#  ('stosować:fin się:qub odpowiednio:adv', 3089),
#  ('określić:ppas w:prep artykuł:brev', 3071),
#  ('dodawać:fin się:qub ustęp:brev', 2699),
#  ('wejść:ger w:prep życie:subst', 2381),
#  ('dzień:subst wejść:ger w:prep', 2099),
#  ('dzień:subst od:prep dzień:subst', 2093),
#  ('wchodzić:fin w:prep życie:subst', 1701),
#  ('w:prep porozumienie:subst z:prep', 1667),
#  ('określić:ppas w:prep ustęp:brev', 1622),
#  ('wprowadzać:fin się:qub następujący:adj', 1613)]

# %% [markdown]
# 12. Use PMI (with 5 occurrence threshold) to compute top 10 results for the trigrams. Devise a method for computing the values, based on the results for bigrams.

# %%
total_trigram_count = sum(trigram_counts.values())
total_lemmitized_trigram_count = sum(lemmatized_trigram_counts.values())

# log2(P(x, y, z) / (P(x) * P(y) * P(z)))
def pmi3(trigram, separator=' '):
    first_token, second_token, third_token = trigram.split(separator)
    first_token_p = unigram_counts[first_token] / total_unigram_count
    second_token_p = unigram_counts[second_token] / total_unigram_count
    third_token_p = unigram_counts[third_token] / total_unigram_count
    trigram_p = trigram_counts[trigram] / total_trigram_count
    return math.log2(trigram_p / (first_token_p * second_token_p * third_token_p))

# log2(P(x, y, z) / (P(x) * P(y) * P(z)))
def lemmatized_pmi3(trigram, separator=' '):
    first_token, second_token, third_token = trigram.split(separator)
    first_token_p = lemmatized_unigram_counts[first_token] / total_lemmitized_unigram_count
    second_token_p = lemmatized_unigram_counts[second_token] / total_lemmitized_unigram_count
    third_token_p = lemmatized_unigram_counts[third_token] / total_lemmitized_unigram_count
    trigram_p = lemmatized_trigram_counts[trigram] / total_lemmitized_trigram_count
    return math.log2(trigram_p / (first_token_p * second_token_p * third_token_p))

# %% [markdown]
# ### Trigrams

# %%
trigram_pmi = {
    trigram: pmi3(trigram)
    for (trigram, count)
    in trigram_counts.items()
}

sorted(trigram_pmi.items(), key=lambda trigram_pmi: -trigram_pmi[1])[:10]
# Out:
# [('virtus et fraternitas', 44.21571342809874),
#  ('salus aegroti suprema', 44.21571342809874),
#  ('aegroti suprema lex', 44.21571342809874),
#  ('ośmioramienna gwiazda policyjna', 44.21571342809874),
#  ('przekazowi pieniężnemu towarzyszyły', 44.21571342809874),
#  ('prawosławnym metropolitą warszawskim', 44.21571342809874),
#  ('mitteldeutsche grundstucksgesellschaft mit', 44.21571342809874),
#  ('grundstucksgesellschaft mit beschrankter', 44.21571342809874),
#  ('mit beschrankter haftung', 44.21571342809874),
#  ('fabryki portland cementu', 44.21571342809874)]

# %%
filtered_trigram_pmi = {
    trigram: pmi
    for (trigram, pmi)
    in trigram_pmi.items()
    if trigram_counts[trigram] >= 5
}

sorted(filtered_trigram_pmi.items(), key=lambda trigram_pmi: -trigram_pmi[1])[:10]
# Out:
# [('finałowego turnieju mistrzostw', 37.05584209132035),
#  ('profilem zaufanym epuap', 36.814833991816556),
#  ('cienką sierścią zwierzęcą', 36.75628180946144),
#  ('przedwczesnego wyrębu drzewostanu', 36.63075092737758),
#  ('centralnemu biuru antykorupcyjnemu', 36.36396438668268),
#  ('turnieju mistrzostw europy', 36.29030734495737),
#  ('potwierdzonym profilem zaufanym', 36.26734619651406),
#  ('szybkiemu postępowi technicznemu', 36.138897831047906),
#  ('piłce nożnej uefa', 36.119789008100206),
#  ('wypalonym paliwem jądrowym', 35.91650540971146)]

# %% [markdown]
# ### Lemmatized Trigrams

# %%
lemmatized_trigram_pmi = {
    trigram: lemmatized_pmi3(trigram)
    for (trigram, count)
    in lemmatized_trigram_counts.items()
}

sorted(lemmatized_trigram_pmi.items(), key=lambda trigram_pmi: -trigram_pmi[1])[:10]
# Out:
# [('salus:subst aegroti:xxx suprema:subst', 44.21827330917656),
#  ('aegroti:xxx suprema:subst lex:xxx', 44.21827330917656),
#  ('mitteldeutsche:subst grundstucksgesellschaft:subst mit:subst',
#   44.21827330917656),
#  ('grundstucksgesellschaft:subst mit:subst beschrankter:subst',
#   44.21827330917656),
#  ('mit:subst beschrankter:subst haftung:subst', 44.21827330917656),
#  ('asistent:subst medical:subst obstetrică:adja', 44.21827330917656),
#  ('staphylococcus:subst aureus:subst wankomycynooporne:xxx',
#   44.21827330917656),
#  ('dosuszać:ger blaszka:subst liściowy:adj', 44.21827330917656),
#  ('chleb:subst świętojański:adj strąkowy:adj', 44.21827330917656),
#  ('wszywać:ger zamek:subst błyskawiczny:adj', 44.21827330917656)]

# %%
filtered_lemmatized_trigram_pmi = {
    trigram: pmi
    for (trigram, pmi)
    in lemmatized_trigram_pmi.items()
    if lemmatized_trigram_counts[trigram] >= 5
}

sorted(filtered_lemmatized_trigram_pmi.items(), key=lambda trigram_pmi: -trigram_pmi[1])[:10]
# Out:
# [('porcelanowy:adj młyn:subst kulowy:adj', 38.08899029223159),
#  ('wymiennik:subst przeponowy:adj rurowy:adj', 37.21827330917656),
#  ('finałowy:adj turniej:subst mistrzostwa:subst', 36.2239198723177),
#  ('vitis:subst vinifera:subst l:brev', 36.05840197239817),
#  ('piłka:subst nożny:adj uefa:subst', 35.4593838764556),
#  ('turniej:subst mistrzostwa:subst europa:subst', 35.022286011148054),
#  ('przedwczesny:adj wyrąb:subst drzewostan:subst', 35.00395418837579),
#  ('mecz:subst piłka:subst nożny:adj', 34.72241828228939),
#  ('profil:subst zaufany:adj epuap:subst', 34.63519054167363),
#  ('milion:brev dolar:subst usa:subst', 34.47343947167702)]

# %% [markdown]
# 14. Answer the following questions:
#   a) Why do we have to filter the bigrams, rather than the token sequence?
#
# So that we don't modify the source text and only considering the result we get from it.
#
#   b) Which method works better for the bigrams and which for the trigrams?
#
# PMI looks to work well for both cases
#
#   c) What types of expressions are discovered by the methods.
#
# PMI finds the sets in which the meaning is matched very well. It gives the highest score to words that have particularly stronged meaning togethe.
#
#   d) Can you devise a different type of filtering that would yield better results?
#
# For example filtering out all prepositions or words that have no real meaning in the context.
